# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.head(10)
# Out:
#   School DBN  ... Percent Scoring CR
# 0     01M034  ...                 na
# 1     01M034  ...                 na
# 2     01M034  ...                 na
# 3     01M140  ...                 na
# 4     01M140  ...                 na
# 5     01M140  ...                 na
# 6     01M140  ...                 na
# 7     01M140  ...                 na
# 8     01M184  ...                 98
# 9     01M184  ...               78.4
#
# [10 rows x 15 columns]

# %%
df['School Name'].unique()
# Out:
# array(['P.S. 034 Franklin D. Roosevelt', 'P.S. 140 Nathan Straus',
#        'P.S. 184m Shuang Wen', ..., 'Family Life Academy Charter School',
#        'Harriet Tubman Charter School', 'Icahn Charter School'],
#       dtype=object)

# %%
df = df.drop(['Total Tested', 'School Level', 'School DBN', 'Number Scoring CR', 'Percent Scoring CR', 'Percent Scoring 65 or Above', 'Number Scoring 80 or Above', 'Number Scoring Below 65', 'Percent Scoring Below 65', 'Number Scoring 65 or Above', 'Percent Scoring 80 or Above'], axis=1)

# %%
df['Mean Score'] = pd.to_numeric(df['Mean Score'], errors= 'coerce')

# %%
df.head()
# Out:
#                       School Name         Regents Exam  Year  Mean Score
# 0  P.S. 034 Franklin D. Roosevelt  Common Core Algebra  2017         NaN
# 1  P.S. 034 Franklin D. Roosevelt   Living Environment  2015        77.9
# 2  P.S. 034 Franklin D. Roosevelt   Living Environment  2016        74.0
# 3          P.S. 140 Nathan Straus  Common Core Algebra  2016         NaN
# 4          P.S. 140 Nathan Straus  Common Core Algebra  2017         NaN

# %%
df.dropna()
# Out:
#                            School Name         Regents Exam  Year  Mean Score
# 1       P.S. 034 Franklin D. Roosevelt   Living Environment  2015        77.9
# 2       P.S. 034 Franklin D. Roosevelt   Living Environment  2016        74.0
# 5               P.S. 140 Nathan Straus   Living Environment  2015        67.4
# 6               P.S. 140 Nathan Straus   Living Environment  2016        72.6
# 7               P.S. 140 Nathan Straus   Living Environment  2017        64.4
# ...                                ...                  ...   ...         ...
# 212321            Icahn Charter School  Common Core Algebra  2016        87.2
# 212322            Icahn Charter School  Common Core Algebra  2017        87.0
# 212323            Icahn Charter School  Common Core Algebra  2017        88.3
# 212324            Icahn Charter School   Living Environment  2015        76.5
# 212325            Icahn Charter School   Living Environment  2015        79.8
#
# [137101 rows x 4 columns]

# %%
df.describe()
# Out:
#                 Year     Mean Score
# count  212331.000000  137109.000000
# mean     2015.956069      65.998967
# std         0.799726      11.288883
# min      2015.000000      15.000000
# 25%      2015.000000      58.300000
# 50%      2016.000000      65.400000
# 75%      2017.000000      73.400000
# max      2017.000000      98.700000

# %%
df.count()
# Out:
# School Name     212331
# Regents Exam    212321
# Year            212331
# Mean Score      137109
# dtype: int64

# %%
#School_list = ['P.S. 034 Franklin D. Roosevelt', 'Harriet Tubman Charter School']

#nfdf = df[df['School Name'].isin(School_list)]
#print(nfdf)

# %%
#first school, Roosevelt Highschool

fdr = df[df['School Name'] == 'P.S. 034 Franklin D. Roosevelt']

# %%
#second school, Icahn Charter School	

ics = df[df['School Name'] == 'Icahn Charter School']

# %%
icsl= ics[df['Regents Exam'] == 'Living Environment']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
fdrc = fdr[df['Regents Exam'] == 'Living Environment']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
fdr.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff783d97450>,
# ...
#       dtype=object)

# %%
fdrc.dropna()
# Out:
#                            School Name        Regents Exam  Year  Mean Score
# 1       P.S. 034 Franklin D. Roosevelt  Living Environment  2015        77.9
# 2       P.S. 034 Franklin D. Roosevelt  Living Environment  2016        74.0
# 19480   P.S. 034 Franklin D. Roosevelt  Living Environment  2015        77.9
# 19481   P.S. 034 Franklin D. Roosevelt  Living Environment  2016        74.0
# 54237   P.S. 034 Franklin D. Roosevelt  Living Environment  2015        78.8
# 102881  P.S. 034 Franklin D. Roosevelt  Living Environment  2015        78.0
# 102882  P.S. 034 Franklin D. Roosevelt  Living Environment  2015        77.9
# 139886  P.S. 034 Franklin D. Roosevelt  Living Environment  2015        80.0
# 139888  P.S. 034 Franklin D. Roosevelt  Living Environment  2015        75.5
# 139892  P.S. 034 Franklin D. Roosevelt  Living Environment  2016        73.5

# %%
fdrc.head()
# Out:
#                           School Name        Regents Exam  Year  Mean Score
# 1      P.S. 034 Franklin D. Roosevelt  Living Environment  2015        77.9
# 2      P.S. 034 Franklin D. Roosevelt  Living Environment  2016        74.0
# 19480  P.S. 034 Franklin D. Roosevelt  Living Environment  2015        77.9
# 19481  P.S. 034 Franklin D. Roosevelt  Living Environment  2016        74.0
# 54236  P.S. 034 Franklin D. Roosevelt  Living Environment  2015         NaN

# %%
fdrc['Mean Score'].value_counts().plot(kind='barh')

# %%
fdrc.mean()
# Out:
# Year          2015.45
# Mean Score      76.75
# dtype: float64

# %%
icsl.mean()
# Out:
# Year          2016.045455
# Mean Score      78.075000
# dtype: float64

# %%
icsl.head()
# Out:
#                 School Name        Regents Exam  Year  Mean Score
# 19474  Icahn Charter School  Living Environment  2015        77.9
# 19475  Icahn Charter School  Living Environment  2016        77.1
# 19476  Icahn Charter School  Living Environment  2017        79.7
# 54230  Icahn Charter School  Living Environment  2015        77.9
# 54231  Icahn Charter School  Living Environment  2016        77.1

# %%
icsl['Mean Score'].value_counts().plot(kind='barh')

# %%
 # %matplotlib inline

# %%
sns.displot(fdrc['Mean Score'])

# %%
sns.displot(icsl['Mean Score'])

# %% [markdown]
# # Description of analysis of two NYC High Schools.
#
# I decided to compare the Mean Scores for two different schools for the Living Environment regents.
#
# **Icahn Charter School** VS. **Franklin D.Roosevelt	**
#
# *All years were included.
#
# I began by filtering the dataset to only provide the columns and rows I was intersted in. Next, I gathered the two means scores for both schools.
# The mean score for Icahn Charter School was 78.075
# while the mean score for F.D.R High school was 76.75.
#
# The two histograms above also give me a slightly better visualization of the information/results I was looking for. It appears that Roosevelt High school has **lower** means scores overall as compared to the mean scores of Icahn Charter School, respectively.

# %%
len(fdrc)
# Out:
# 20
